# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
paragraph = nlp("I am going to University today.")

# %%
paragraph.text
# Out:
# 'I am going to University today.'

# %%
paragraph[1]
# Out:
# am

# %%
paragraph[1].pos_
# Out:
# 'AUX'

# %%
paragraph[4].pos_
# Out:
# 'PROPN'

# %%
paragraph[4].tag_
# Out:
# 'NNP'

# %%
spacy.explain("PROPN")
# Out:
# 'proper noun'

# %%
for word in paragraph:
  print(word.text,"-------", word.pos_, word.tag_, spacy.explain(word.tag_))
# Out:
# I ------- PRON PRP pronoun, personal
# am ------- AUX VBP verb, non-3rd person singular present
# going ------- VERB VBG verb, gerund or present participle
# to ------- ADP IN conjunction, subordinating or preposition
# University ------- PROPN NNP noun, proper singular
# today ------- NOUN NN noun, singular or mass
# . ------- PUNCT . punctuation mark, sentence closer

# %%
para1 = nlp("I washed the floor when the painter had gone")

for word in para1:
  print(word.text,"-------", word.pos_, word.tag_, spacy.explain(word.tag_))
# Out:
# I ------- PRON PRP pronoun, personal
# washed ------- VERB VBD verb, past tense
# the ------- DET DT determiner
# floor ------- NOUN NN noun, singular or mass
# when ------- SCONJ WRB wh-adverb
# the ------- DET DT determiner
# painter ------- NOUN NN noun, singular or mass
# had ------- AUX VBD verb, past tense
# gone ------- VERB VBN verb, past participle

# %%
para2 = nlp("The new lamp had good light for reading.")

for word in para2:
  print(word.text,"-------", word.pos_, word.tag_, spacy.explain(word.tag_))
# Out:
# The ------- DET DT determiner
# new ------- ADJ JJ adjective (English), other noun-modifier (Chinese)
# lamp ------- NOUN NN noun, singular or mass
# had ------- VERB VBD verb, past tense
# good ------- ADJ JJ adjective (English), other noun-modifier (Chinese)
# light ------- NOUN NN noun, singular or mass
# for ------- ADP IN conjunction, subordinating or preposition
# reading ------- NOUN NN noun, singular or mass
# . ------- PUNCT . punctuation mark, sentence closer

# %%
para3 = nlp("Rahul likes to travel light.")

for word in para3:
  print(word.text,"-------", word.pos_, word.tag_, spacy.explain(word.tag_))
# Out:
# Rahul ------- NOUN NN noun, singular or mass
# likes ------- VERB VBZ verb, 3rd person singular present
# to ------- PART TO infinitival "to"
# travel ------- VERB VB verb, base form
# light ------- NOUN NN noun, singular or mass
# . ------- PUNCT . punctuation mark, sentence closer

# %%
para4 = nlp("A Quick Brown Fox jumps over the Lazy Dog ")

# %%
from spacy import displacy

# %%
displacy.render(para4, style = "dep", jupyter = True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="130480f9b19141e388fd6b567670c48d-0" class="displacy" width="1625" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Quick</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">Brown</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">Fox</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">jumps</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">over</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Lazy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Dog</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-130480f9b19141e388fd6b567670c48d-0-0" stroke-width="2px" d="M70,264.5 C70,89.5 570.0,89.5 570.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-130480f9b19141e388fd6b567670c48d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-130480f9b19141e388fd6b567670c48d-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-130480f9b19141e388fd6b567670c48d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-130480f9b19141e388fd6b567670c48d-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-130480f9b19141e388fd6b567670c48d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-130480f9b19141e388fd6b567670c48d-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-130480f9b19141e388fd6b567670c48d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,266.5 L587,254.5 603,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-130480f9b19141e388fd6b567670c48d-0-4" stroke-width="2px" d="M770,264.5 C770,177.0 915.0,177.0 915.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-130480f9b19141e388fd6b567670c48d-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M915.0,266.5 L923.0,254.5 907.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-130480f9b19141e388fd6b567670c48d-0-5" stroke-width="2px" d="M1120,264.5 C1120,89.5 1445.0,89.5 1445.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-130480f9b19141e388fd6b567670c48d-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,266.5 L1112,254.5 1128,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-130480f9b19141e388fd6b567670c48d-0-6" stroke-width="2px" d="M1295,264.5 C1295,177.0 1440.0,177.0 1440.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-130480f9b19141e388fd6b567670c48d-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,266.5 L1287,254.5 1303,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-130480f9b19141e388fd6b567670c48d-0-7" stroke-width="2px" d="M945,264.5 C945,2.0 1450.0,2.0 1450.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-130480f9b19141e388fd6b567670c48d-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1450.0,266.5 L1458.0,254.5 1442.0,254.5" fill="currentColor"/>
# </g>
# </svg></span>

# %%
options={
    "distance": 80,
    "compact": True,
    "color": "#fff",
    "bg": "black"
}

# %%
displacy.render(para4, style = "dep", jupyter = True, options = options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a009065e23c84b0ebb337041c3a40570-0" class="displacy" width="770" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: #fff; background: black; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">Quick</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">Brown</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Fox</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">jumps</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">over</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">Lazy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">Dog</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a009065e23c84b0ebb337041c3a40570-0-0" stroke-width="2px" d="M62,122.0 62,95.33333333333333 287.0,95.33333333333333 287.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a009065e23c84b0ebb337041c3a40570-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,124.0 L58,116.0 66,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a009065e23c84b0ebb337041c3a40570-0-1" stroke-width="2px" d="M142,122.0 142,108.66666666666667 204.0,108.66666666666667 204.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a009065e23c84b0ebb337041c3a40570-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M142,124.0 L138,116.0 146,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a009065e23c84b0ebb337041c3a40570-0-2" stroke-width="2px" d="M222,122.0 222,108.66666666666667 284.0,108.66666666666667 284.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a009065e23c84b0ebb337041c3a40570-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M222,124.0 L218,116.0 226,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a009065e23c84b0ebb337041c3a40570-0-3" stroke-width="2px" d="M302,122.0 302,108.66666666666667 364.0,108.66666666666667 364.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a009065e23c84b0ebb337041c3a40570-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M302,124.0 L298,116.0 306,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a009065e23c84b0ebb337041c3a40570-0-4" stroke-width="2px" d="M382,122.0 382,108.66666666666667 444.0,108.66666666666667 444.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a009065e23c84b0ebb337041c3a40570-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M444.0,124.0 L448.0,116.0 440.0,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a009065e23c84b0ebb337041c3a40570-0-5" stroke-width="2px" d="M542,122.0 542,95.33333333333333 687.0,95.33333333333333 687.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a009065e23c84b0ebb337041c3a40570-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M542,124.0 L538,116.0 546,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a009065e23c84b0ebb337041c3a40570-0-6" stroke-width="2px" d="M622,122.0 622,108.66666666666667 684.0,108.66666666666667 684.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a009065e23c84b0ebb337041c3a40570-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M622,124.0 L618,116.0 626,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a009065e23c84b0ebb337041c3a40570-0-7" stroke-width="2px" d="M462,122.0 462,82.0 690.0,82.0 690.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a009065e23c84b0ebb337041c3a40570-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M690.0,124.0 L694.0,116.0 686.0,116.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
para5 = nlp("NASA has released new details on the initial phases of its architecture to return humans to the moon as a step towards eventual missions to Mars.")

for token in para5:
    print(token," | ", token.pos_, " | ", spacy.explain(token.pos_))
# Out:
# NASA  |  PROPN  |  proper noun
# has  |  AUX  |  auxiliary
# released  |  VERB  |  verb
# new  |  ADJ  |  adjective
# details  |  NOUN  |  noun
# on  |  ADP  |  adposition
# the  |  DET  |  determiner
# initial  |  ADJ  |  adjective
# phases  |  NOUN  |  noun
# of  |  ADP  |  adposition
# its  |  PRON  |  pronoun
# architecture  |  NOUN  |  noun
# to  |  PART  |  particle
# return  |  VERB  |  verb
# humans  |  NOUN  |  noun
# to  |  ADP  |  adposition
# the  |  DET  |  determiner
# moon  |  NOUN  |  noun
# as  |  ADP  |  adposition
# a  |  DET  |  determiner
# step  |  NOUN  |  noun
# towards  |  ADP  |  adposition
# eventual  |  ADJ  |  adjective
# missions  |  NOUN  |  noun
# to  |  ADP  |  adposition
# Mars  |  PROPN  |  proper noun
# .  |  PUNCT  |  punctuation

# %%
para6 = nlp("Elon Musk’s SpaceX made final preparations to launch its powerful new Starship rocket system into space for the first time on a brief but highly anticipated, uncrewed test flight from the Texas coast.")

for token in para6:
    print(token," | ", token.pos_, " | ", spacy.explain(token.pos_), " | ", token.tag_, " | ", spacy.explain(token.tag_))
# Out:
# Elon  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# Musk  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# ’s  |  PART  |  particle  |  POS  |  possessive ending
# SpaceX  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# made  |  VERB  |  verb  |  VBD  |  verb, past tense
# final  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# preparations  |  NOUN  |  noun  |  NNS  |  noun, plural
# to  |  PART  |  particle  |  TO  |  infinitival "to"
# launch  |  VERB  |  verb  |  VB  |  verb, base form
# its  |  PRON  |  pronoun  |  PRP$  |  pronoun, possessive
# powerful  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# new  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# Starship  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# rocket  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# system  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# into  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# space  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# for  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# first  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# time  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# on  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# a  |  DET  |  determiner  |  DT  |  determiner
# brief  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# but  |  CCONJ  |  coordinating conjunction  |  CC  |  conjunction, coordinating
# highly  |  ADV  |  adverb  |  RB  |  adverb
# anticipated  |  VERB  |  verb  |  VBN  |  verb, past participle
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# uncrewed  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# test  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# flight  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# from  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# Texas  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# coast  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer

# %%
para7 = nlp("Papai quits the job")

print(para7[1].text, "|", para7[1].tag_, "|", spacy.explain(para7[1].tag_))
# Out:
# quits | VBZ | verb, 3rd person singular present

# %%
para8 = nlp("Papai quit the job")

print(para8[1].text, "|", para8[1].tag_, "|", spacy.explain(para8[1].tag_))
# Out:
# quit | VBD | verb, past tense

# %%
nasa = """COLORADO SPRINGS — NASA has released new details on the initial phases of its architecture to return humans to the moon as a step towards eventual missions to Mars.

Speaking at the 38th Space Symposium April 18, NASA Deputy Administrator Pam Melroy rolled out a 150-page document describing its plans for the initial series of Artemis missions to the moon and how they fit into a set of more than 60 objectives for its long-term plans for human missions to the moon and Mars.

“The architecture concept review details plans for early human exploration of the moon’s south pole,” she said. “It provides more definition for plans through Artemis 4 and sets the stage for the first crewed missions to Mars.”

The document describes how the various programs in development fit together to carry out those missions, such as the Space Launch System, Orion, Gateway and Human Landing System. Those programs are linked to specific objectives, functions and use cases for those missions.

Along with the architecture document, NASA released several white papers to explain aspects of the architecture, such as the use of the near-rectilinear halo orbit around the moon and the Gateway that will operate in it.

“I think they provide a very succinct description of why we’re doing what we’re doing, and especially how the Artemis missions to the moon are going to reduce the risk for future Mars missions,” Melroy said of the white papers.

The document extends, at a higher level, to future phases of Artemis with sustained lunar exploration and later human missions to Mars. “We’re going to learn a lot on the way so we’re not ready to talk about sustained presence yet on Mars,” she explained, “but we have the shape there.”

Other NASA officials have noted tweaks to earlier plans for later phases of Artemis, such as a shift from a single “base camp” at the lunar south pole to several sites that could be visited on later Artemis missions.

Jim Free, NASA associate administrator for exploration systems development, said at an April 17 briefing that, because of changing lighting conditions at the south pole, missing a launch window for a particular site might delay a mission there by months. “We could maybe have two or three sites to go to that help our science diversity,” he said.

The architecture was developed internally at NASA, but Melroy said there will be opportunities for industry and international partners to provide input. “We identified some areas for collaboration,” she said, although the architecture doesn’t spell out specific procurement plans. “It does help show where we are and where we’re headed, and we know how important that is for our industry and international partners.”

Melroy said that NASA plans forums this summer where those commercial and international partners will be able to offer feedback on the architecture, as well as workshops organized by professional societies. That feedback will assist NASA’s next round of architecture development, which will be done on annual cycles starting in November to work on later missions.

“NASA has positioned this strategy for longevity and success,” she said. “This is a critical milestone for us in our moon-to-Mars strategy. We feel very aligned with our partners. We want to continue to stay that way."""

para9 = nlp(nasa)

filtered_tokens = []

for token in para9:
  if token.pos_ not in ["SPACE", "PUNCT", "whitespace"]:
    filtered_tokens.append(token)
     
     #print(token," | ", token.pos_, " | ", spacy.explain(token.pos_), " | ", token.tag_, " | ", spacy.explain(token.tag_))

# %%
filtered_tokens
# Out:
# [COLORADO,
#  SPRINGS,
#  NASA,
#  has,
#  released,
#  new,
#  details,
#  on,
#  the,
#  initial,
#  phases,
#  of,
#  its,
#  architecture,
#  to,
#  return,
#  humans,
#  to,
#  the,
#  moon,
#  as,
#  a,
#  step,
#  towards,
#  eventual,
#  missions,
#  to,
#  Mars,
#  Speaking,
#  at,
#  the,
#  38th,
#  Space,
#  Symposium,
#  April,
#  18,
#  NASA,
#  Deputy,
#  Administrator,
#  Pam,
#  Melroy,
#  rolled,
#  out,
#  a,
#  150,
#  page,
#  document,
#  describing,
#  its,
#  plans,
#  for,
#  the,
#  initial,
#  series,
#  of,
#  Artemis,
#  missions,
#  to,
#  the,
#  moon,
#  and,
#  how,
#  they,
#  fit,
#  into,
#  a,
#  set,
#  of,
#  more,
#  than,
#  60,
#  objectives,
#  for,
#  its,
#  long,
#  term,
#  plans,
#  for,
#  human,
#  missions,
#  to,
#  the,
#  moon,
#  and,
#  Mars,
#  The,
#  architecture,
#  concept,
#  review,
#  details,
#  plans,
#  for,
#  early,
#  human,
#  exploration,
#  of,
#  the,
#  moon,
#  ’s,
#  south,
#  pole,
#  she,
#  said,
#  It,
#  provides,
#  more,
#  definition,
#  for,
#  plans,
#  through,
#  Artemis,
#  4,
#  and,
#  sets,
#  the,
#  stage,
#  for,
#  the,
#  first,
#  crewed,
#  missions,
#  to,
#  Mars,
#  The,
#  document,
#  describes,
#  how,
#  the,
#  various,
#  programs,
#  in,
#  development,
#  fit,
#  together,
#  to,
#  carry,
#  out,
#  those,
#  missions,
#  such,
#  as,
#  the,
#  Space,
#  Launch,
#  System,
#  Orion,
#  Gateway,
#  and,
#  Human,
#  Landing,
#  System,
#  Those,
#  programs,
#  are,
#  linked,
#  to,
#  specific,
#  objectives,
#  functions,
#  and,
#  use,
#  cases,
#  for,
#  those,
#  missions,
#  Along,
#  with,
#  the,
#  architecture,
#  document,
#  NASA,
#  released,
#  several,
#  white,
#  papers,
#  to,
#  explain,
#  aspects,
#  of,
#  the,
#  architecture,
#  such,
#  as,
#  the,
#  use,
#  of,
#  the,
#  near,
#  rectilinear,
#  halo,
#  orbit,
#  around,
#  the,
#  moon,
#  and,
#  the,
#  Gateway,
#  that,
#  will,
#  operate,
#  in,
#  it,
#  I,
#  think,
#  they,
#  provide,
#  a,
#  very,
#  succinct,
#  description,
#  of,
#  why,
#  we,
#  ’re,
#  doing,
#  what,
#  we,
#  ’re,
#  doing,
#  and,
#  especially,
#  how,
#  the,
#  Artemis,
#  missions,
#  to,
#  the,
#  moon,
#  are,
#  going,
#  to,
#  reduce,
#  the,
#  risk,
#  for,
#  future,
#  Mars,
#  missions,
#  Melroy,
#  said,
#  of,
#  the,
#  white,
#  papers,
#  The,
#  document,
#  extends,
#  at,
#  a,
#  higher,
#  level,
#  to,
#  future,
#  phases,
#  of,
#  Artemis,
#  with,
#  sustained,
#  lunar,
#  exploration,
#  and,
#  later,
#  human,
#  missions,
#  to,
#  Mars,
#  We,
#  ’re,
#  going,
#  to,
#  learn,
#  a,
#  lot,
#  on,
#  the,
#  way,
#  so,
#  we,
#  ’re,
#  not,
#  ready,
#  to,
#  talk,
#  about,
#  sustained,
#  presence,
#  yet,
#  on,
#  Mars,
#  she,
#  explained,
#  but,
#  we,
#  have,
#  the,
#  shape,
#  there,
#  Other,
#  NASA,
#  officials,
#  have,
#  noted,
#  tweaks,
#  to,
#  earlier,
#  plans,
#  for,
#  later,
#  phases,
#  of,
#  Artemis,
#  such,
#  as,
#  a,
#  shift,
#  from,
#  a,
#  single,
#  base,
#  camp,
#  at,
#  the,
#  lunar,
#  south,
#  pole,
#  to,
#  several,
#  sites,
#  that,
#  could,
#  be,
#  visited,
#  on,
#  later,
#  Artemis,
#  missions,
#  Jim,
#  Free,
#  NASA,
#  associate,
#  administrator,
#  for,
#  exploration,
#  systems,
#  development,
#  said,
#  at,
#  an,
#  April,
#  17,
#  briefing,
#  that,
#  because,
#  of,
#  changing,
#  lighting,
#  conditions,
#  at,
#  the,
#  south,
#  pole,
#  missing,
#  a,
#  launch,
#  window,
#  for,
#  a,
#  particular,
#  site,
#  might,
#  delay,
#  a,
#  mission,
#  there,
#  by,
#  months,
#  We,
#  could,
#  maybe,
#  have,
#  two,
#  or,
#  three,
#  sites,
#  to,
#  go,
#  to,
#  that,
#  help,
#  our,
#  science,
#  diversity,
#  he,
#  said,
#  The,
#  architecture,
#  was,
#  developed,
#  internally,
#  at,
#  NASA,
#  but,
#  Melroy,
#  said,
#  there,
#  will,
#  be,
#  opportunities,
#  for,
#  industry,
#  and,
#  international,
#  partners,
#  to,
#  provide,
#  input,
#  We,
#  identified,
#  some,
#  areas,
#  for,
#  collaboration,
#  she,
#  said,
#  although,
#  the,
#  architecture,
#  does,
#  n’t,
#  spell,
#  out,
#  specific,
#  procurement,
#  plans,
#  It,
#  does,
#  help,
#  show,
#  where,
#  we,
#  are,
#  and,
#  where,
#  we,
#  ’re,
#  headed,
#  and,
#  we,
#  know,
#  how,
#  important,
#  that,
#  is,
#  for,
#  our,
#  industry,
#  and,
#  international,
#  partners,
#  Melroy,
#  said,
#  that,
#  NASA,
#  plans,
#  forums,
#  this,
#  summer,
#  where,
#  those,
#  commercial,
#  and,
#  international,
#  partners,
#  will,
#  be,
#  able,
#  to,
#  offer,
#  feedback,
#  on,
#  the,
#  architecture,
#  as,
#  well,
#  as,
#  workshops,
#  organized,
#  by,
#  professional,
#  societies,
#  That,
#  feedback,
#  will,
#  assist,
#  NASA,
#  ’s,
#  next,
#  round,
#  of,
#  architecture,
#  development,
#  which,
#  will,
#  be,
#  done,
#  on,
#  annual,
#  cycles,
#  starting,
#  in,
#  November,
#  to,
#  work,
#  on,
#  later,
#  missions,
#  NASA,
#  has,
#  positioned,
#  this,
#  strategy,
#  for,
#  longevity,
#  and,
#  success,
#  she,
#  said,
#  This,
#  is,
#  a,
#  critical,
#  milestone,
#  for,
#  us,
#  in,
#  our,
#  moon,
#  to,
#  Mars,
#  strategy,
#  We,
#  feel,
#  very,
#  aligned,
#  with,
#  our,
#  partners,
#  We,
#  want,
#  to,
#  continue,
#  to,
#  stay,
#  that,
#  way]

# %%
count = para9.count_by(spacy.attrs.POS)
count
# Out:
# {92: 127,
#  97: 76,
#  96: 44,
#  87: 27,
#  100: 67,
#  84: 53,
#  85: 79,
#  90: 53,
#  95: 40,
#  94: 16,
#  103: 11,
#  93: 7,
#  89: 17,
#  98: 12,
#  86: 13}

# %%
para9.vocab[85].text
# Out:
# 'ADP'

# %%
for k,v in count.items():
    print(para9.vocab[k].text, "|",v)
# Out:
# NOUN | 127
# PUNCT | 76
# PROPN | 44
# AUX | 27
# VERB | 67
# ADJ | 53
# ADP | 79
# DET | 53
# PRON | 40
# PART | 16
# SPACE | 11
# NUM | 7
# CCONJ | 17
# SCONJ | 12
# ADV | 13

# %%
options={
    "distance": 80,
    "compact": True,
    "color": "black",
    "bg": "lightblue"
}

# %%
displacy.render(para9, style = "dep", jupyter = True, options = options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="12bb66fd0b03499bb287527ebaa0a2d2-0" class="displacy" width="45330" height="417.0" direction="ltr" style="max-width: none; height: 417.0px; color: black; background: lightblue; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">COLORADO</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">SPRINGS —</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">NASA</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">released</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">new</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">details</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">initial</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">phases</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">architecture</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">return</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">humans</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1410">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1410">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1570">moon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">step</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1890">towards</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1890">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">eventual</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">missions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2130">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2130">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">Mars.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2290">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2290">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2370">Speaking</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="327.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">AD
